# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniffernayoung/pythonclass/blob/main/Python_%EA%B0%80%EC%83%81%EB%A8%B8%EC%8B%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Virtual Machine

# %% [markdown]
# ___

# %% [markdown]
# ## 파이썬 가상머신

# %% [markdown]
# *   <font color = "red"> 자바가상머신과 유사한 스택 기반 가상머신
#
#
#
# *   레지스터 기반 가상 머신 및 레지스터 스택이 있는 실제 머신과는 다르게 작동
# *   모든 명령어가 스택에 대한 푸시작업 및 팝 작업을 유발한다는 것
#
# *   더 많은 함수 호출을 생성하고 어떻게든 레지스터 기반 가상 머신보다 더 느리거나 더 많은 노력이 필요 할 수도 있다.

# %% [markdown]
# ![파이썬 가상머신.png](data:image/png;base64,...)
#
# [출처] http://pages.cpsc.ucalgary.ca/~aycock/papers/ipc7-211.pdf

# %% [markdown]
# ## Java 가상머신

# %% [markdown]
# *   스택 기반의 가상머신
# *   단일 상속 형태의 객체 지향 프로그래밍을 가상 머신 수준을 구현
#
# *   두 가상 머신처럼 스택 기반이어서 대다수의 명령어가 스택 선두에서 피연산자를 택하고 결과는 다시 스택에 넣는다.
# *   스택에서 가져올 피연산자의 타입을 명령어에 지정

# %% [markdown]
# ![java.png](data:image/png;base64,...)
#
# [출처]https://ko.wikipedia.org/wiki/%EC%9E%90%EB%B0%94_%EA%B0%80%EC%83%81_%EB%A8%B8%EC%8B%A0
#
# 이미지, 참조

# %% [markdown]
# 1.   자바가상머신은 대부분의 운영 체제는 물론, 인터넷 익스프롤러와 같은 웹 브라우저 등 여러가지 플랫폼에 설치되어 사용될 수 있으며, 휴대전화나 가전기기에도 설치가 가능하다.
#
# 2.   자바플랫폼은 여러 플랫폼을 지원하여, 사용자의 특정한 요구대로 만들어 제공하는 프로그램으로써 운영체제와 응용 소프트웨어의 중간에서 조정과 중개의 역을 수행과 플랫폼 스스로의 역할을 동시에 할수 있다.

# %% [markdown]
# ## 파이썬 가상환경

# %% [markdown]
# *   원하는 python 환경을 구축하기 위해 필요한 모듈을 담아 놓은 바구니
# *   마구 설치하다보면 충돌이 일어날 수 있기 때문에 충돌을 방지 하기 위해
#
#
# *   하나의 컴퓨터에 서로 다른 버전의 파이썬과 라이브러리를 실행
# *   python프로그램을 사용하고자 할때 최소한의 환경으로 실행하기 위해 github 저장소를 네트워크와 연계하고자 할 때 사용

# %% [markdown]
# ![파이썬 가상환경2.png](data:image/png;base64,...)
#
#
# [출처]https://dojang.io/mod/page/view.php?id=2470

# %% [markdown]
# 안녕하세요
